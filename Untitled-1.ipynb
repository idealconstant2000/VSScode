# %%
import numpy as np

arr = np.array([3, 2, 0, 1])

print(np.sort(arr))
# Out:
# [0 1 2 3]

# %%
pip install numpy
# Out:
# Collecting numpy
#   Using cached numpy-2.3.3-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Using cached numpy-2.3.3-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
# Installing collected packages: numpy
# Successfully installed numpy-2.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
arr = np.array(['banana', 'cherry', 'apple'])

print(np.sort(arr))
# Out:
# ['apple' 'banana' 'cherry']

# %%
arr = np.array([True, False, True])

print(np.sort(arr))
# Out:
# [False  True  True]

# %%
arr = np.array([[3, 2, 4], [5, 0, 1]])

print(np.sort(arr))
# Out:
# [[2 3 4]
#  [0 1 5]]

# %%
arr = np.array([41, 42, 43, 44])

x = [True, False, True, False]

newarr = arr[x]

print(newarr)
# Out:
# [41 43]

# %%
arr = np.array([41, 42, 43, 44])

# Create an empty list
filter_arr = []

# go through each element in arr
for element in arr:
  # if the element is higher than 42, set the value to True, otherwise False:
  if element > 42:
    filter_arr.append(True)
  else:
    filter_arr.append(False)

newarr = arr[filter_arr]

print(filter_arr)
print(newarr)
# Out:
# [False, False, True, True]
# [43 44]

# %%
arr = np.array([1, 2, 3, 4, 5, 6, 7])

# Create an empty list
filter_arr = []

# go through each element in arr
for element in arr:
  # if the element is completely divisble by 2, set the value to True, otherwise False
  if element % 2 == 0:
    filter_arr.append(True)
  else:
    filter_arr.append(False)

newarr = arr[filter_arr]

print(filter_arr)
print(newarr)
# Out:
# [False, True, False, True, False, True, False]
# [2 4 6]

# %%
x = None

# %%
import numpy as np

# %%
arr = np.array([41, 42, 43, 44])

filter_arr = arr > 42

newarr = arr[filter_arr]

print(filter_arr)
print(newarr)
# Out:
# [False False  True  True]
# [43 44]

# %%
arr = np.array([1, 2, 3, 4, 5, 6, 7])

filter_arr = arr % 2 == 0

newarr = arr[filter_arr]

print(filter_arr)
print(newarr)
# Out:
# [False  True False  True False  True False]
# [2 4 6]

# %%
from numpy import random

x = random.randint(100)

print(x)
# Out:
# 91

# %%
from numpy import random

x = random.rand()

print(x)
# Out:
# 0.16448217597282722

# %%
x=random.randint(100, size=(5))

print(x)
# Out:
# [83 97 91 26 22]

# %%
x = random.randint(100, size=(3, 5))

print(x)
# Out:
# [[31 13 38 29 33]
#  [21 77 50  7 89]
#  [58 78 15 54 73]]

# %%
x = random.rand(5)

print(x)
# Out:
# [0.82720885 0.84497167 0.98318737 0.12593838 0.04255911]

# %%
x = random.rand(3, 5)

print(x)
# Out:
# [[0.8067499  0.49803039 0.43686339 0.25168299 0.27449446]
#  [0.74098837 0.99875094 0.10512322 0.14597059 0.39940649]
#  [0.54202995 0.24275062 0.988284   0.64211069 0.02000987]]

# %%
x = random.choice([3, 5, 7, 9])

print(x)
# Out:
# 7

# %%
x = random.choice([3, 5, 7, 9], size=(3, 5))

print(x)
# Out:
# [[3 5 5 9 7]
#  [9 5 7 5 3]
#  [3 9 9 3 5]]

# %%
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(100))

print(x)
# Out:
# [5 7 7 7 7 3 7 7 3 7 5 5 7 5 7 7 7 5 5 7 7 7 3 5 7 7 7 7 3 5 7 3 7 7 5 3 7
#  7 5 3 7 7 3 3 7 7 7 7 7 5 7 7 7 5 7 5 7 7 7 7 7 5 7 7 7 7 7 7 5 7 7 7 7 7
#  5 7 7 7 7 7 7 7 3 3 7 7 7 5 7 7 3 5 7 5 3 7 3 7 5 7]

# %%
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3, 5))

print(x)
# Out:
# [[3 7 7 5 7]
#  [7 5 7 3 3]
#  [3 5 7 5 7]]

# %%
from numpy import random
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

random.shuffle(arr)

print(arr)
# Out:
# [1 4 5 2 3]

# %%
arr = np.array([1, 2, 3, 4, 5])

print(random.permutation(arr))
# Out:
# [2 3 5 1 4]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot([0, 1, 2, 3, 4, 5])

plt.show()

# %%
sns.displot([0, 1, 2, 3, 4, 5], kind="kde")

plt.show()

# %%
sns.displot([0, 1, 2, 3, 4, 5], kind="hist", kde=True)

# %%
x = random.normal(size=(2, 3))

print(x)
# Out:
# [[ 1.12665376 -0.43074736  1.84108819]
#  [ 0.26601946 -2.94960682 -1.85824795]]

# %%
x = random.normal(loc=1, scale=2, size=(2, 3))

print(x)
# Out:
# [[ 0.83843165 -1.03730801  1.75490537]
#  [ 1.45562417  0.9746045  -1.13200107]]

# %%
sns.displot(random.normal(size=1000), kind="kde")

plt.show()

# %%
x = random.binomial(n=10, p=0.5, size=10)

print(x)
# Out:
# [4 4 6 5 6 4 6 4 6 5]

# %%
sns.displot(random.binomial(n=10, p=0.5, size=1000))

plt.show()

# %%
data = {
  "normal": random.normal(loc=50, scale=5, size=1000),
  "binomial": random.binomial(n=100, p=0.5, size=1000)
}

sns.displot(data, kind="kde")

plt.show()

# %%
x = random.poisson(lam=2, size=10)

print(x)
# Out:
# [3 2 4 1 0 1 0 3 2 1]

# %%
sns.displot(random.poisson(lam=2, size=1000))

plt.show()

# %%
data = {
  "normal": random.normal(loc=50, scale=7, size=1000),
  "poisson": random.poisson(lam=50, size=1000)
}

sns.displot(data, kind="kde")

plt.show()

# %%
data = {
  "binomial": random.binomial(n=1000, p=0.01, size=1000),
  "poisson": random.poisson(lam=10, size=1000)
}

sns.displot(data, kind="kde")

plt.show()

# %%
x = random.uniform(size=(2, 3))

print(x)
# Out:
# [[0.18793352 0.47247846 0.46727538]
#  [0.02975903 0.07443521 0.01342379]]

# %%
sns.displot(random.uniform(size=1000), kind="kde")

plt.show()

# %%
x = random.logistic(loc=1, scale=2, size=(2, 3))

print(x)
# Out:
# [[ 3.28993469  2.30803211  2.04740386]
#  [ 1.48966995  0.6731104  -3.27821036]]

# %%
sns.displot(random.logistic(loc=1, scale=2,size=1000), kind="kde")

plt.show()

# %%
data = {
  "normal": random.normal(scale=2, size=1000),
  "logistic": random.logistic(size=1000)
}

sns.displot(data, kind="kde")

plt.show()

# %%
x = random.multinomial(n=6, pvals=[1/6, 1/6, 1/6, 1/6, 1/6, 1/6])

print(x)
# Out:
# [3 1 0 1 0 1]

# %%
x = random.exponential(scale=2, size=(2, 3))

print(x)
# Out:
# [[0.48141961 0.4948498  2.26046373]
#  [2.27563635 0.24846787 0.18577168]]

# %%
sns.displot(random.exponential(size=1000), kind="kde")

plt.show()

# %%
x = random.chisquare(df=2, size=(2, 3))

print(x)
# Out:
# [[1.22035283 2.65359665 3.98866513]
#  [0.58054613 3.40643527 0.12416622]]

# %%
sns.displot(random.chisquare(df=1, size=1000), kind="kde")

plt.show()

# %%
x = random.rayleigh(scale=2, size=(2, 3))

print(x)
# Out:
# [[2.58352339 4.68742785 2.40302515]
#  [3.73337047 2.08768166 3.75366872]]

# %%
sns.displot(random.rayleigh(size=1000), kind="kde")

plt.show()

# %%
x = random.pareto(a=2, size=(2, 3))

print(x)
# Out:
# [[0.02040247 0.98747498 2.61136665]
#  [7.1722966  2.47452894 1.13328739]]

# %%
sns.displot(random.pareto(a=2, size=1000))

plt.show()

# %%
x = random.zipf(a=2, size=(2, 3))

print(x)
# Out:
# [[1 1 3]
#  [3 1 1]]

# %%
x = random.zipf(a=2, size=1000)
sns.displot(x[x<10])

plt.show()

# %%
x = [1, 2, 3, 4]
y = [4, 5, 6, 7]
z = []

for i, j in zip(x, y):
  z.append(i + j)
print(z)
# Out:
# [5, 7, 9, 11]

# %%
import numpy as np

x = [1, 2, 3, 4]
y = [4, 5, 6, 7]
z = np.add(x, y)

print(z)
# Out:
# [ 5  7  9 11]

# %%
def myadd(x, y):
  return x+y

myadd = np.frompyfunc(myadd, 2, 1)

print(myadd([1, 2, 3, 4], [5, 6, 7, 8]))
# Out:
# [6 8 10 12]

# %%
print(type(np.add))
# Out:
# <class 'numpy.ufunc'>

# %%
print(type(np.concatenate))
# Out:
# <class 'numpy._ArrayFunctionDispatcher'>

# %%
print (type(myadd))
# Out:
# <class 'numpy.ufunc'>

# %%
print(type(np.blahblah))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 print(type(np.blahblah))
#
# File ~/VSScode/.venv/lib/python3.13/site-packages/numpy/__init__.py:795, in __getattr__(attr)
#     792     import numpy.char as char
#     793     return char.chararray
# --> 795 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'blahblah'

# %%
if type(np.add) == np.ufunc:
  print('add is ufunc')
else:
  print('add is not ufunc')
# Out:
# add is ufunc

# %%
arr1 = np.array([10, 11, 12, 13, 14, 15])
arr2 = np.array([20, 21, 22, 23, 24, 25])

newarr = np.add(arr1, arr2)

print(newarr)
# Out:
# [30 32 34 36 38 40]

# %%
arr1 = np.array([10, 20, 30, 40, 50, 60])
arr2 = np.array([20, 21, 22, 23, 24, 25])

newarr = np.subtract(arr1, arr2)

print(newarr)
# Out:
# [-10  -1   8  17  26  35]

# %%
arr1 = np.array([10, 20, 30, 40, 50, 60])
arr2 = np.array([20, 21, 22, 23, 24, 25])

newarr = np.multiply(arr1, arr2)

print(newarr)
# Out:
# [ 200  420  660  920 1200 1500]

# %%
arr1 = np.array([10, 20, 30, 40, 50, 60])
arr2 = np.array([3, 5, 10, 8, 2, 33])

newarr = np.divide(arr1, arr2)

print(newarr)
# Out:
# [ 3.33333333  4.          3.          5.         25.          1.81818182]

# %%
arr1 = np.array([10, 20, 30, 40, 50, 60])
arr2 = np.array([3, 5, 6, 8, 2, 33])

newarr = np.power(arr1, arr2)

print(newarr)
# Out:
# [         1000       3200000     729000000 6553600000000          2500
#              0]

# %%
arr1 = np.array([10, 20, 30, 40, 50, 60])
arr2 = np.array([3, 7, 9, 8, 2, 33])

newarr = np.mod(arr1, arr2)

print(newarr)
# Out:
# [ 1  6  3  0  0 27]

# %%
arr1 = np.array([10, 20, 30, 40, 50, 60])
arr2 = np.array([3, 7, 9, 8, 2, 33])

newarr = np.remainder(arr1, arr2)

print(newarr)
# Out:
# [ 1  6  3  0  0 27]

# %%
arr1 = np.array([10, 20, 30, 40, 50, 60])
arr2 = np.array([3, 7, 9, 8, 2, 33])

newarr = np.divmod(arr1, arr2)

print(newarr)
# Out:
# (array([ 3,  2,  3,  5, 25,  1]), array([ 1,  6,  3,  0,  0, 27]))

# %%
arr = np.array([-1, -2, 1, 2, 3, -4])

newarr = np.absolute(arr)

print(newarr)
# Out:
# [1 2 1 2 3 4]

# %%
arr = np.trunc([-3.1666, 3.6667])

print(arr)
# Out:
# [-3.  3.]

# %%
arr = np.fix([-3.1666, 3.6667])

print(arr)
# Out:
# [-3.  3.]

# %%
arr = np.around(3.1666, 2)

print(arr)
# Out:
# 3.17

# %%
arr = np.floor([-3.1666, 3.6667])

print(arr)
# Out:
# [-4.  3.]

# %%
arr = np.floor([-3.1666, 3.6667])

print(arr)
# Out:
# [-4.  3.]

# %%
arr = np.ceil([-3.1666, 3.6667])

print(arr)
# Out:
# [-3.  4.]

# %%
arr = np.arange(1, 10)

print(np.log2(arr))
# Out:
# [0.         1.         1.5849625  2.         2.32192809 2.5849625
#  2.80735492 3.         3.169925  ]

# %%
arr = np.arange(1, 10)

print(np.log10(arr))
# Out:
# [0.         0.30103    0.47712125 0.60205999 0.69897    0.77815125
#  0.84509804 0.90308999 0.95424251]

# %%
arr = np.arange(1, 10)

print(np.log(arr))
# Out:
# [0.         0.69314718 1.09861229 1.38629436 1.60943791 1.79175947
#  1.94591015 2.07944154 2.19722458]

# %%
nplog = np.frompyfunc(log, 2, 1)

print(nplog(100, 15))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 nplog = np.frompyfunc(log, 2, 1)
#       3 print(nplog(100, 15))
#
# NameError: name 'log' is not defined

# %%
from math import log
nplog = np.frompyfunc(log, 2, 1)

print(nplog(100, 15))
# Out:
# 1.7005483074552052

# %%
arr1 = np.array([1, 2, 3])
arr2 = np.array([1, 2, 3])

newarr = np.add(arr1, arr2)

print(newarr)
# Out:
# [2 4 6]

# %%
arr1 = np.array([1, 2, 3])
arr2 = np.array([1, 2, 3])

newarr = np.sum([arr1, arr2])

print(newarr)
# Out:
# 12

# %%
arr1 = np.array([1, 2, 3])
arr2 = np.array([1, 2, 3])

newarr = np.sum([arr1, arr2], axis=1)

print(newarr)
# Out:
# [6 6]

# %%
arr = np.array([1, 2, 3])

newarr = np.cumsum(arr)

print(newarr)
# Out:
# [1 3 6]

# %%
arr = np.array([1, 2, 3, 4])

x = np.prod(arr)

print(x)
# Out:
# 24

# %%
arr1 = np.array([1, 2, 3, 4])
arr2 = np.array([5, 6, 7, 8])

x = np.prod([arr1, arr2])

print(x)
# Out:
# 40320

# %%
arr1 = np.array([1, 2, 3, 4])
arr2 = np.array([5, 6, 7, 8])

newarr = np.prod([arr1, arr2], axis=1)

print(newarr)
# Out:
# [  24 1680]

# %%
arr = np.array([5, 6, 7, 8])

newarr = np.cumprod(arr)

print(newarr)
# Out:
# [   5   30  210 1680]

# %%
arr = np.array([10, 15, 25, 5])

newarr = np.diff(arr)

print(newarr)
# Out:
# [  5  10 -20]

# %%
arr = np.array([10, 15, 25, 5])

newarr = np.diff(arr, n=2)

print(newarr)
# Out:
# [  5 -30]

# %%
arr = np.array([1, 2, 3, 4])
newarr = np.diff(arr, n=2)

# %%
print(newarr)
# Out:
# [0 0]

# %%
num1 = 4
num2 = 6

x = np.lcm(num1, num2)

print(x)
# Out:
# 12

# %%
arr = np.array([3, 6, 9])

x = np.lcm.reduce(arr)

print(x)
# Out:
# 18

# %%
arr = np.arange(1, 11)

x = np.lcm.reduce(arr)

print(x)
# Out:
# 2520

# %%
num1 = 6
num2 = 9

x = np.gcd(num1, num2)

print(x)
# Out:
# 3

# %%
arr = np.array([20, 8, 32, 36, 16])

x = np.gcd.reduce(arr)

print(x)
# Out:
# 4

# %%
x = np.sin(np.pi/2)

print(x)
# Out:
# 1.0

# %%
arr = np.array([np.pi/2, np.pi/3, np.pi/4, np.pi/5])

x = np.sin(arr)

print(x)
# Out:
# [1.         0.8660254  0.70710678 0.58778525]

# %%
arr = np.array([90, 180, 270, 360])

x = np.deg2rad(arr)

print(x)
# Out:
# [1.57079633 3.14159265 4.71238898 6.28318531]

# %%
arr = np.array([np.pi/2, np.pi, 1.5*np.pi, 2*np.pi])

x = np.rad2deg(arr)

print(x)
# Out:
# [ 90. 180. 270. 360.]

# %%
x = np.arcsin(1.0)

print(x)
# Out:
# 1.5707963267948966

# %%
arr = np.array([1, -1, 0.1])

x = np.arcsin(arr)

print(x)
# Out:
# [ 1.57079633 -1.57079633  0.10016742]

# %%
base = 3
perp = 4

x = np.hypot(base, perp)

print(x)
# Out:
# 5.0

# %%
x = np.sinh(np.pi/2)

print(x)
# Out:
# 2.3012989023072947

# %%
arr = np.array([np.pi/2, np.pi/3, np.pi/4, np.pi/5])

x = np.cosh(arr)

print(x)
# Out:
# [2.50917848 1.60028686 1.32460909 1.20397209]

# %%
x = np.arcsinh(1.0)

print(x)
# Out:
# 0.881373587019543

# %%
arr = np.array([0.1, 0.2, 0.5])

x = np.arctanh(arr)

print(x)
# Out:
# [0.10033535 0.20273255 0.54930614]

# %%
arr = np.array([1, 1, 1, 2, 3, 4, 5, 5, 6, 7])

x = np.unique(arr)

print(x)
# Out:
# [1 2 3 4 5 6 7]

# %%
arr1 = np.array([1, 2, 3, 4])
arr2 = np.array([3, 4, 5, 6])

newarr = np.union1d(arr1, arr2)

print(newarr)
# Out:
# [1 2 3 4 5 6]

# %%
arr1 = np.array([1, 2, 3, 4])
arr2 = np.array([3, 4, 5, 6])

newarr = np.intersect1d(arr1, arr2, assume_unique=True)

print(newarr)
# Out:
# [3 4]

# %%
set1 = np.array([1, 2, 3, 4])
set2 = np.array([3, 4, 5, 6])

newarr = np.setdiff1d(set1, set2, assume_unique=True)

print(newarr)
# Out:
# [1 2]

# %%
set1 = np.array([1, 2, 3, 4])
set2 = np.array([3, 4, 5, 6])

newarr = np.setxor1d(set1, set2, assume_unique=True)

print(newarr)
# Out:
# [1 2 5 6]

# %%
arr.type(set1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 arr.type(set1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'

# %%
arr=np.array(set1,dtype='f'))
# Out:
#   Cell In[122], line 1
#     arr=np.array(set1,dtype='f'))
#                                 ^
# SyntaxError: unmatched ')'

# %%
arr = np.array([1,2,3])
print(np.cumsum(arr))
# Out:
# [1 3 6]

# %%
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = np.median(speed)

print(x)
# Out:
# 87.0

# %%
import numpy

# %%
from scipy import stats
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = stats.mode(speed)

print(x)
# Out:
# ModeResult(mode=np.int64(86), count=np.int64(3))

# %%
speed = [86,87,88,86,87,85,86]

x = numpy.std(speed)

print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 speed = [86,87,88,86,87,85,86]
# ----> 3 x = numpy.std(speed)
#       5 print(x)
#
# NameError: name 'numpy' is not defined

# %%
import numpy
speed = [86,87,88,86,87,85,86]

x = numpy.std(speed)

print(x)
# Out:
# 0.9035079029052513

# %%
speed = [32,111,138,28,59,77,97]

x = numpy.std(speed)

print(x)
# Out:
# 37.84501153334721

# %%
speed = [32,111,138,28,59,77,97]

x = numpy.var(speed)

print(x)
# Out:
# 1432.2448979591834

# %%
speed = [32,111,138,28,59,77,97]

x = numpy.std(speed)

print(x)
# Out:
# 37.84501153334721

# %%
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]

x = numpy.percentile(ages, 75)

print(x)
# Out:
# 43.0

# %%
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]

x = numpy.percentile(ages, 90)

print(x)
# Out:
# 61.0

# %%
x = numpy.random.uniform(0.0, 5.0, 250)

print(x)
# Out:
# [1.61975073 1.8036411  1.66174444 2.28216867 3.35287793 4.15432335
#  4.5406042  4.74769319 1.14605641 1.77034388 0.83095063 3.89594877
#  4.1361685  0.23907116 3.31195384 1.5595994  2.14935478 2.68270128
#  0.60290494 4.00230307 3.165258   3.39986233 0.33283875 3.18147089
#  0.90698049 2.21100148 4.05621785 1.89195011 2.31492402 3.28064563
#  0.18285274 3.78946228 1.01207296 2.7796017  3.89066797 3.37016767
#  1.89584038 4.33641174 0.28651206 1.16018018 0.95896179 3.99037246
#  4.905412   3.45897155 4.04769974 4.96524225 2.46697672 2.80913164
#  4.43281694 2.30908068 4.41126495 3.08688173 3.2955084  2.08205804
#  1.14189137 3.86383322 3.68366209 1.28897263 2.75835627 2.13398035
#  3.85332357 3.90506641 2.86124277 2.3160732  4.12716693 2.22129822
#  0.55437303 0.48679528 3.0477973  4.85608476 1.89276714 1.0548241
#  1.5990703  4.92825798 3.1917783  1.76137566 2.38144484 1.72231788
#  3.808426   1.17990707 1.94316816 2.38383774 2.21889764 2.58181073
#  4.25007191 1.21380419 1.7149565  4.81177194 1.95722141 2.38115061
#  3.18675813 3.63955375 4.10497983 2.42193743 4.29323149 2.55501992
#  1.70932945 3.7579955  1.02225934 4.74911905 1.70303706 1.49711214
#  3.68872928 0.04632943 4.45050612 2.21848982 3.13844425 0.87739802
#  4.20679424 1.99741216 1.25262046 2.31688942 2.20611986 3.16992084
#  4.23803233 1.90258273 0.53239785 1.63061939 1.86629136 0.72016267
#  0.06942037 0.17346065 3.34702827 3.42500427 1.88751059 3.13240411
#  1.45578792 3.48854941 4.26455609 3.76025964 1.19608143 0.14185996
#  0.17726303 0.90589182 0.06424861 3.7037611  4.87317383 3.46391798
#  3.61494978 4.96586957 1.67239972 4.07579407 3.06220078 4.30250285
#  4.30852207 4.44086328 4.39013864 4.02677723 2.51073456 3.51605268
#  4.62356987 0.71348717 0.72783111 3.97467097 3.89032422 2.69145184
#  0.53571841 3.14251843 3.16820897 2.95748143 2.97669741 0.89625139
#  1.45455219 4.4199691  1.33524023 1.71574362 2.09010255 4.98264397
#  0.72845409 2.68515519 3.67905927 1.73071487 1.25217144 3.902352
#  2.64999285 3.960419   3.6597583  3.23126509 1.71087341 4.06148462
#  0.86244429 1.31695594 1.68681984 4.66404547 3.54927904 1.99515921
#  4.06711311 1.69460742 4.2758799  3.29979917 1.0844076  4.28435824
#  1.13647167 4.65481566 3.03458744 1.10758476 1.51759722 4.78850149
#  1.29024241 3.76813901 2.23460002 3.36000893 4.08530177 1.81373034
#  4.35619533 2.56924202 2.10134791 4.91720172 0.70043105 0.30855547
#  3.37024315 0.86689081 0.99256656 1.73125717 0.68243573 4.10529177
#  3.12888948 3.7849362  0.53086134 2.69423891 2.51043195 2.1370405
#  2.84142269 0.02804838 3.63615716 1.70433192 3.36877212 0.32882089
#  3.20751755 1.99286022 2.92004931 3.35264948 2.27725035 3.3873755
#  4.29841489 1.84272047 4.33046556 2.47217501 1.44584202 0.96121034
#  2.45891316 1.83820524 1.98114489 2.45427286 4.49293373 4.5242339
#  4.78293591 4.62270119 2.25921231 4.98444597]

# %%
import matplotlib.pyplot as plt

x = numpy.random.uniform(0.0, 5.0, 250)

plt.hist(x, 5)
plt.show()

# %%
x = numpy.random.uniform(0.0, 5.0, 100000)

plt.hist(x, 100)
plt.show()

# %%
x = numpy.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
x = numpy.random.normal(5.0, 1.0, 1000)
y = numpy.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)
plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

print(r)
# Out:
# -0.7585915243761551

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

speed = myfunc(10)

print(speed)
# Out:
# 85.59308314937454

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x, y)

print(r)
# Out:
# 0.01331814154297493

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

plt.scatter(x, y)
plt.show()

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from sklearn.metrics import r2_score
#       3 x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
#       4 y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.9432150416451025

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

speed = mymodel(17)
print(speed)
# Out:
# 88.87331269697975

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(2, 95, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.009952707566680541

# %%
import pandas
